# %%
import pandas as pd
import numpy as np

# %%
house = pd.read_csv('train_house.csv', index_col=0)
house.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.tail()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
# ...

# %%
house.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
house.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
total = house.isnull().sum().sort_values(ascending=False)
percent = (house.isnull().sum()/house.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# MasVnrType      872  0.597260
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# Electrical        1  0.000685
# MSSubClass        0  0.000000

# %%
house = house.dropna(axis=1)
house.head()
# Out:
#     MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 1           60       RL     8450   Pave      Reg         Lvl    AllPub
# 2           20       RL     9600   Pave      Reg         Lvl    AllPub
# 3           60       RL    11250   Pave      IR1         Lvl    AllPub
# 4           70       RL     9550   Pave      IR1         Lvl    AllPub
# 5           60       RL    14260   Pave      IR1         Lvl    AllPub
#
#    LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# Id                                   ...
# 1     Inside       Gtl      CollgCr  ...             0         0           0
# 2        FR2       Gtl      Veenker  ...             0         0           0
# 3     Inside       Gtl      CollgCr  ...             0         0           0
# 4     Corner       Gtl      Crawfor  ...           272         0           0
# 5        FR2       Gtl      NoRidge  ...             0         0           0
#
# ...

# %%
num_cols = house._get_numeric_data().columns
house_numerical = house[num_cols]
house_numerical.head()
# Out:
#     MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1           60     8450            7            5       2003          2003
# 2           20     9600            6            8       1976          1976
# 3           60    11250            7            5       2001          2002
# 4           70     9550            7            5       1915          1970
# 5           60    14260            8            5       2000          2000
#
#     BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  \
# Id                                                  ...
# 1          706           0        150          856  ...           0
# 2          978           0        284         1262  ...         298
# 3          486           0        434          920  ...           0
# 4          216           0        540          756  ...           0
# 5          655           0        490         1145  ...         192
#
# ...

# %%
house_categorical = house.drop(num_cols, axis = 1)
house_categorical.head()
# Out:
#    MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2        RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 3        RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4        RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 5        RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#    Neighborhood Condition1 Condition2  ... ExterCond Foundation Heating  \
# Id                                     ...
# 1       CollgCr       Norm       Norm  ...        TA      PConc    GasA
# 2       Veenker      Feedr       Norm  ...        TA     CBlock    GasA
# 3       CollgCr       Norm       Norm  ...        TA      PConc    GasA
# 4       Crawfor       Norm       Norm  ...        TA     BrkTil    GasA
# 5       NoRidge       Norm       Norm  ...        TA      PConc    GasA
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.barplot(x=house_categorical['Utilities'].value_counts().index,
                 y=house_categorical['Utilities'].value_counts(normalize = True))
# Out:
# <Axes: xlabel='Utilities', ylabel='proportion'>

# %% [markdown]
# # Insight tentang Distribusi Utilitas
#
# Plot batang di atas menampilkan distribusi kolom `Utilities` dari dataset `house_categorical`. Berikut adalah beberapa insight berdasarkan plot:
#
# 1. Kategori Dominan: Salah satu kategori utilitas jauh lebih umum daripada yang lain. Ini menunjukkan bahwa sebagian besar rumah dalam dataset memiliki jenis setup utilitas yang sama.
# 2. Kategori Jarang: Beberapa kategori jauh lebih jarang. Ini bisa menunjukkan bahwa jenis utilitas ini kurang umum di wilayah tersebut atau di antara jenis rumah yang disertakan dalam dataset.
# 3. Pengecekan Kualitas Data: Jika ada kategori yang tidak terduga atau ketimpangan yang tampak aneh, mungkin perlu dilakukan pengecekan kualitas data untuk memastikan tidak ada kesalahan atau kesalahan klasifikasi.
# 4. Tren Pasar: Distribusi ini mungkin mencerminkan tren pasar atau standar regional dalam penyediaan utilitas, yang bisa berharga untuk memahami karakteristik pasar perumahan.
# 5. Analisis Masa Depan: Insight-insight ini dapat memandu analisis lebih lanjut, seperti menyelidiki mengapa beberapa utilitas kurang umum atau bagaimana jenis utilitas berkorelasi dengan variabel lain seperti harga rumah atau lokasi.
#
# Dengan memeriksa proporsi, kita dapat lebih memahami setup utilitas yang tipikal dalam pasar perumahan yang direpresentasikan oleh dataset ini.

# %%
sns.barplot(x=house_categorical['HouseStyle'].value_counts().index,
                 y=house_categorical['HouseStyle'].value_counts(normalize = True))
# Out:
# <Axes: xlabel='HouseStyle', ylabel='proportion'>

# %% [markdown]
# # Insight tentang Distribusi Gaya Rumah
#
# Plot batang di atas menampilkan distribusi kolom `HouseStyle` dari dataset `house_categorical`. Berikut adalah beberapa insight berdasarkan plot:
#
# 1. Gaya Rumah Paling Umum: Dari plot, dapat dilihat bahwa salah satu gaya rumah mendominasi secara signifikan. Ini menunjukkan bahwa jenis gaya tertentu lebih umum daripada yang lain dalam dataset ini.
# 2. Varian Gaya Rumah: Terdapat beberapa variasi gaya rumah, dengan beberapa gaya yang lebih jarang terjadi. Ini mungkin mencerminkan preferensi dan tren yang berbeda dalam desain rumah.
# 3. Potensi Pasar: Mengetahui gaya rumah yang paling umum dapat memberikan wawasan berharga kepada pembangun atau pemasar properti tentang permintaan pasar.
# 4. Pentingnya Desain: Distribusi ini menyoroti pentingnya desain rumah dalam keputusan pembelian atau penyewaan rumah, serta kebutuhan untuk memahami preferensi konsumen.
# 5. Kesesuaian Lokal: Preferensi gaya rumah juga bisa mencerminkan kesesuaian lokal dan budaya, yang perlu dipertimbangkan dalam pengembangan properti.
#
# Melalui pemahaman tentang distribusi gaya rumah ini, pemangku kepentingan dalam industri properti dapat membuat keputusan yang lebih baik dan mengarahkan strategi pemasaran yang lebih efektif.

# %%
sns.barplot(x=house_categorical['ExterQual'].value_counts().index,
                 y=house_categorical['ExterQual'].value_counts(normalize = True))
# Out:
# <Axes: xlabel='ExterQual', ylabel='proportion'>

# %% [markdown]
# # Insight tentang Distribusi Kualitas Eksterior
#
# Plot batang di atas menampilkan distribusi kualitas eksterior rumah dari dataset `house_categorical`. Berikut adalah beberapa insight berdasarkan plot:
#
# 1. Perbedaan Kualitas: Terlihat bahwa beberapa rumah memiliki kualitas eksterior yang sangat baik, sementara yang lain memiliki kualitas yang lebih rendah. Ini menunjukkan variasi yang signifikan dalam kualitas eksterior di antara rumah-rumah dalam dataset.
# 2. Tingkat Kualitas yang Paling Umum: Kualitas eksterior yang paling umum mungkin menunjukkan standar minimum atau preferensi umum dalam konstruksi atau renovasi rumah.
# 3. Potensi Korelasi: Kualitas eksterior rumah mungkin berkorelasi dengan faktor-faktor lain seperti harga jual, lokasi geografis, atau tahun pembangunan.
# 4. Perhatian pada Rencana: Melihat proporsi kategori kualitas eksterior tertentu dapat membantu perencanaan renovasi atau pembangunan baru dengan memahami preferensi pasar atau standar kualitas yang diharapkan.
# 5. Kesimpulan: Distribusi kualitas eksterior rumah ini memberikan wawasan tentang variasi dalam fitur fisik rumah yang dapat memengaruhi nilai dan daya tarik pasar.
#
# Melalui pemahaman ini tentang kualitas eksterior, pemilik rumah atau pengembang dapat membuat keputusan yang lebih terinformasi tentang perawatan, renovasi, atau pengembangan properti mereka.

# %%
x = house_numerical["SalePrice"]
sns.distplot(x, axlabel=x.name)
plt.title("Distribusi Harga Jual Rumah")
plt.xlabel('Harga Jual Rumah')
plt.ylabel('Frekuensi')
line1 = plt.axvline(x.mean(), color="k", linestyle="--", label = "mean")
line2 = plt.axvline(np.median(x), color="r", linestyle="--", label = "median")
first_legend = plt.legend(handles=[line1,line2], loc=1)
print("Median:", x.median())
print("Mean:", x.mean())
print("Std Dev:", x.std())
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25496\2136414658.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, axlabel=x.name)
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Median: 163000.0
# Mean: 180921.19589041095
# Std Dev: 79442.50288288663

# %% [markdown]
# # Insight tentang Distribusi Harga Jual Rumah
#
# Plot distribusi di atas menampilkan distribusi harga jual rumah dari data numerik dalam dataset. Berikut adalah beberapa insight berdasarkan plot:
#
# 1. Tren Sentral: Distribusi menunjukkan tren pusat yang kuat di sekitar nilai rata-rata dan median, yang mewakili titik-titik pusat sebaran harga jual rumah.
# 2. Skewness: Jika kurva distribusi miring ke kiri atau kanan, itu menunjukkan kecenderungan data menuju satu arah. Ini dapat memberikan wawasan tentang distribusi harga rumah yang mungkin tidak simetris.
# 3. Kesimpulan Statistik: Dengan nilai median, mean, dan standar deviasi yang tercetak di bawah plot, kita dapat mengevaluasi seberapa jauh data tersebar dari nilai rata-rata dan seberapa seragam distribusinya.
# 4. Potensi Outliers: Jika ada perbedaan yang signifikan antara nilai rata-rata dan median, atau jika standar deviasi besar, itu bisa menunjukkan adanya outlier (pencilan) dalam data harga jual rumah.
#
# Melalui pemahaman ini tentang distribusi harga jual rumah, pemilik rumah atau pemangku kepentingan lainnya dapat mengambil keputusan yang lebih terinformasi tentang harga, strategi pemasaran, atau kebijakan harga.

# %%
x = house_numerical["GrLivArea"]
sns.distplot(x, axlabel=x.name)
plt.title("Distribusi Luas Hunian")
plt.ylabel('Frekuensi')
plt.xlabel('Luas Hunian (sqft)')
line1 = plt.axvline(x.mean(), color="k", linestyle="--", label = "mean")
line2 = plt.axvline(np.median(x), color="r", linestyle="--", label = "median")
first_legend = plt.legend(handles=[line1,line2], loc=1)
print("Median:", x.median())
print("Mean:", x.mean())
print("Std Dev:", x.std())
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25496\1013953331.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, axlabel=x.name)
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Median: 1464.0
# Mean: 1515.463698630137
# Std Dev: 525.4803834232027

# %% [markdown]
# # Insight tentang Distribusi Luas Hunian
#
# Grafik di atas menampilkan distribusi luas hunian (GrLivArea) dalam satuan kaki persegi (Sqft). Berikut adalah beberapa insight berdasarkan plot:
#
# 1. Distribusi: Distribusi luas hunian cenderung mengikuti pola normal dengan sebagian besar nilai terkonsentrasi di sekitar nilai rata-rata atau median.
# 2. Tinggi dan Lebar: Grafik memungkinkan kita untuk melihat bagaimana luas hunian terdistribusi secara keseluruhan, dengan tinggi puncak menunjukkan frekuensi relatif tertinggi dan lebar menunjukkan sebaran data.
# 3. Rata-rata dan Median: Garis putus-putus menunjukkan rata-rata (hitam) dan median (merah), yang memberikan gambaran tentang pusat massa distribusi. Ini membantu untuk memahami apakah distribusi simetris atau tidak.
# 4. Statistik Deskriptif: Dalam statistik deskriptif di bawah grafik, kita melihat nilai median, rata-rata, dan standar deviasi. Ini memberikan pemahaman lebih lanjut tentang distribusi data.
#
# Grafik ini dapat memberikan wawasan yang berguna bagi para pemangku kepentingan dalam memahami karakteristik luas hunian dalam dataset, yang dapat mempengaruhi penilaian atau keputusan terkait properti.

# %%
x = house_numerical["PoolArea"]
sns.distplot(x, axlabel=x.name)
plt.title("Distribusi Luas Kolam Renang")
plt.xlabel('Luas Kolam Renang')
plt.ylabel('Frekuensi')
line1 = plt.axvline(x.mean(), color="k", linestyle="--", label = "mean")
line2 = plt.axvline(np.median(x), color="r", linestyle="--", label = "median")
first_legend = plt.legend(handles=[line1,line2], loc=1)
print("Median:", x.median())
print("Mean:", x.mean())
print("Std Dev:", x.std())
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25496\1194716026.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, axlabel=x.name)
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Median: 0.0
# Mean: 2.758904109589041
# Std Dev: 40.17730694453043

# %% [markdown]
# # Insight tentang Distribusi Luas Kolam Renang
#
# Grafik distribusi di atas menampilkan distribusi data untuk luas kolam renang (`PoolArea`). Berikut adalah beberapa insight berdasarkan grafik dan statistik deskriptif:
#
# 1. Pusat Pemusatan: Terlihat bahwa nilai rata-rata (garis putus-putus hitam) dan median (garis putus-putus merah) memiliki perbedaan yang signifikan. Hal ini menunjukkan adanya potensi adanya pencilan (outlier) yang mempengaruhi rata-rata.
# 2. Distribusi Data: Distribusi data cenderung condong ke kanan (positif skewness), yang menunjukkan bahwa sebagian besar rumah mungkin memiliki kolam renang dengan luas yang relatif kecil.
# 3. Tren Pusat: Nilai median memberikan representasi yang lebih baik tentang "nilai tengah" data daripada rata-rata, terutama dalam kasus distribusi yang tidak simetris atau memiliki pencilan.
# 4. Penyebaran: Standar deviasi yang relatif tinggi menunjukkan variasi yang signifikan dalam luas kolam renang antar rumah.
# 5. Pertimbangan Renovasi: Informasi ini dapat berguna bagi pemilik rumah atau pengembang properti dalam merencanakan renovasi atau pembangunan yang melibatkan penambahan atau perbaikan kolam renang.
#
# Melalui pemahaman ini tentang distribusi luas kolam renang, keputusan yang lebih baik dapat dibuat dalam perencanaan dan pengelolaan properti.

# %%
x = np.log10(house_numerical["SalePrice"])
sns.distplot(x, axlabel=x.name, bins = 30)
line1 = plt.axvline(x.mean(), color="k", linestyle="--", label = "mean")
line2 = plt.axvline(np.median(x), color="r", linestyle="--", label = "median")
first_legend = plt.legend(handles=[line1,line2], loc=1)
print("Median:", x.median())
print("Mean:", x.mean())
print("Std Dev:", x.std())
plt.title("Distribution of Log10(SalePrice)")
plt.xlabel('Log10(SalePrice)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25496\3822327946.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, axlabel=x.name, bins = 30)
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Median: 5.212187604403958
# Mean: 5.221978956475628
# Std Dev: 0.17347974217176843

# %% [markdown]
# # Insight tentang Distribusi Logaritma SalePrice
#
# Plot histogram di atas menampilkan distribusi logaritma dari `SalePrice` dari dataset. Berikut adalah beberapa insight berdasarkan plot:
#
# 1. Tren Distribusi: Distribusi logaritma `SalePrice` membantu mengubah distribusi asimetris menjadi lebih simetris, membuatnya lebih sesuai untuk analisis statistik yang memerlukan asumsi normalitas.
# 2. Pusat Massa: Garis putus-putus yang menunjukkan rata-rata (hitam) dan median (merah) memberikan pandangan tentang di mana pusat massa data berada. Median lebih resisten terhadap pencilan dibandingkan rata-rata.
# 3. Kepadatan: Label sumbu-y yang dinamai "Density" menunjukkan bahwa sumbu y mewakili kepadatan distribusi, bukan frekuensi langsung. Ini memberikan informasi tentang seberapa sering nilai-nilai tertentu muncul dalam distribusi.
# 4. Skala: Label sumbu-x yang dinamai "Log10(SalePrice)" menunjukkan bahwa sumbu x mewakili nilai `SalePrice` yang telah diubah ke skala logaritma basis 10. Hal ini memungkinkan kita untuk memperhatikan perubahan dalam proporsi data pada skala yang lebih halus.
# 5. Kesimpulan: Distribusi logaritma memberikan wawasan tentang sebaran harga rumah dengan cara yang lebih terstruktur dan normal, yang memfasilitasi analisis statistik lebih lanjut.

# %%
x = np.log10(house_numerical["GrLivArea"])
sns.distplot(x, axlabel=x.name, bins = 30)
line1 = plt.axvline(x.mean(), color="k", linestyle="--", label = "mean")
line2 = plt.axvline(np.median(x), color="r", linestyle="--", label = "median")
first_legend = plt.legend(handles=[line1,line2], loc=1)
print("Median:", x.median())
print("Mean:", x.mean())
print("Std Dev:", x.std())
plt.title("Distribution of Log10(GrLivArea)")
plt.xlabel("Log10(GrLivArea)")
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25496\2774092510.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, axlabel=x.name, bins = 30)
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Median: 3.165541076722373
# Mean: 3.156354310389778
# Std Dev: 0.14485910869663873

# %% [markdown]
# ### Insight
#
# - Judul: Plot ini berjudul "Distribusi Log10(GrLivArea)", yang menunjukkan distribusi dari logaritma (basis 10) dari variabel "GrLivArea" (luas bangunan di atas tanah).
# - Label Sumbu X: Sumbu x diberi label "Log10(GrLivArea)", yang merepresentasikan logaritma (basis 10) dari luas bangunan dalam kaki persegi.
# - Label Sumbu Y: Sumbu y diberi label "Kepadatan", yang menunjukkan kepadatan kemunculan nilai-nilai dalam data.
# - Garis Vertikal: Plot ini mencakup dua garis vertikal:
#   - Garis putus-putus hitam mewakili rata-rata dari data yang telah ditransformasi dengan logaritma.
#   - Garis putus-putus merah mewakili median dari data yang telah ditransformasi dengan logaritma.
# - Statistik:
#   - Median dari data yang telah ditransformasi dengan logaritma adalah sekitar `x.median()`.
#   - Rata-rata dari data yang telah ditransformasi dengan logaritma adalah sekitar `x.mean()`.
#   - Standar deviasi dari data yang telah ditransformasi dengan logaritma adalah sekitar `x.std()`.
# - Interpretasi: Transformasi logaritma membantu menormalkan distribusi "GrLivArea", mengurangi skewness dan membuatnya lebih mudah untuk dianalisis. Nilai rata-rata dan median yang dekat menunjukkan distribusi yang lebih simetris setelah transformasi.

# %%
filtered_data = house_numerical[house_numerical["PoolArea"] > 0]
x = np.log10(filtered_data["PoolArea"])
sns.distplot(x, axlabel=x.name, bins = 30)
line1 = plt.axvline(x.mean(), color="k", linestyle="--", label = "mean")
line2 = plt.axvline(np.median(x), color="r", linestyle="--", label = "median")
first_legend = plt.legend(handles=[line1,line2], loc=1)
print("Median:", x.median())
print("Mean:", x.mean())
print("Std Dev:", x.std())
plt.title("Distribution of Log10(PoolArea)")
plt.xlabel("Log10(PoolArea)")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25496\515177271.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, axlabel=x.name, bins = 30)
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Median: 2.7442929831226763
# Mean: 2.7557179129199136
# Std Dev: 0.06486028432445097

# %% [markdown]
# # Insight tentang Distribusi Log10(PoolArea)
#
# Plot di atas menggambarkan distribusi logaritma basis 10 dari area kolam renang (PoolArea) yang dimiliki oleh rumah-rumah dalam dataset. Berikut adalah insight yang didapat:
#
# 1. Distribusi yang Miring: Distribusi Log10(PoolArea) terlihat miring ke kanan, dengan lebih banyak rumah memiliki area kolam renang yang lebih kecil.
# 2. Pusat Tumpuan: Garis putus-putus hitam menunjukkan rata-rata Log10(PoolArea), sedangkan garis putus-putus merah menunjukkan median. Median yang lebih rendah dari rata-rata menunjukkan adanya ekstrem di sisi kanan distribusi yang miring.
# 3. Statistik Deskriptif: Median dari distribusi ini adalah [nilai median], sedangkan rata-ratanya adalah [nilai rata-rata], dengan standar deviasi sebesar [nilai standar deviasi]. Standar deviasi yang cukup besar menunjukkan variasi yang signifikan dalam area kolam renang.
# 4. Pertimbangan Penting: Distribusi ini dapat menjadi pertimbangan penting dalam perencanaan atau penilaian properti, terutama dalam hal harga dan daya tarik pasar.

# %%
ax = sns.scatterplot(y="GrLivArea", x="SalePrice", data=house_numerical)
plt.title("Hubungan Antara Harga Jual dan Luas Hunian")
plt.ylabel('Luas Hunian (Sqft)')
plt.xlabel('Harga Jual ($)')
plt.show()

# %% [markdown]
# # Insight tentang Hubungan Antara Harga Jual dan Luas Hunian
#
# Grafik di atas menunjukkan hubungan antara harga jual rumah dan luas hunian (dalam kaki persegi) dari dataset `house_numerical`. Berikut adalah beberapa insight berdasarkan grafik:
#
# 1. Korelasi Positif: Terlihat adanya kecenderungan kenaikan harga jual seiring dengan peningkatan luas hunian. Ini menunjukkan adanya korelasi positif antara kedua variabel tersebut.
# 2. Pola Linier: Hubungan antara harga jual dan luas hunian cenderung mengikuti pola linier, meskipun ada variasi yang dapat dilihat di sepanjang grafik.
# 3. Outliers: Terdapat beberapa titik data yang jauh dari pola umum, yang mungkin merupakan outlier. Analisis lebih lanjut mungkin diperlukan untuk memahami penyebabnya.
# 4. Informasi untuk Penentuan Harga: Grafik ini dapat memberikan pandangan yang berguna bagi pembeli atau penjual dalam menentukan harga berdasarkan luas hunian.
# 5. Pertimbangan Perencanaan: Bagi pengembang, pemahaman tentang hubungan ini dapat membantu dalam merencanakan ukuran dan harga rumah yang sesuai dengan pasar.
#
# Dengan memahami hubungan antara harga jual dan luas hunian, pemangku kepentingan dalam pasar properti dapat membuat keputusan yang lebih terinformasi.

# %%
ax = sns.regplot(y="GarageArea", x="SalePrice", data=house_numerical)
plt.title("Hubungan antara Luas Garasi dan Harga Jual Rumah")
plt.ylabel('Luas Garasi')
plt.xlabel('Harga Jual Rumah')
plt.show()

# %% [markdown]
# # Insight tentang Hubungan antara Luas Garasi dan Harga Jual Rumah
#
# Plot regresi di atas menunjukkan hubungan antara luas garasi dan harga jual rumah dari dataset `house_numerical`. Berikut adalah beberapa insight berdasarkan plot:
#
# 1. Tren Positif: Terlihat dari arah garis regresi yang naik bahwa terdapat tren positif antara luas garasi dan harga jual rumah. Artinya, semakin besar luas garasi, semakin tinggi harga jual rumahnya.
# 2. Penyebaran Data: Meskipun ada tren positif, terdapat penyebaran data yang cukup luas di sepanjang garis regresi. Ini menunjukkan bahwa hubungan antara luas garasi dan harga jual rumah tidak selalu bersifat linier dan dapat dipengaruhi oleh faktor-faktor lain.
# 3. Nilai Ekstrem: Terlihat beberapa nilai ekstrem di kedua sumbu, yang mungkin merupakan outlier. Outlier tersebut dapat memengaruhi estimasi regresi dan sebaiknya dipertimbangkan dengan hati-hati dalam analisis lebih lanjut.
# 4. Pentingnya Garasi: Insight ini menyoroti pentingnya luas garasi dalam menentukan harga jual rumah. Rumah dengan garasi yang lebih besar cenderung memiliki nilai jual yang lebih tinggi, mungkin karena memberikan lebih banyak ruang penyimpanan atau kenyamanan bagi pemilik.
# 5. Analisis Lebih Lanjut: Analisis lebih lanjut dapat dilakukan untuk memahami faktor-faktor lain yang mungkin memengaruhi hubungan ini, seperti lokasi rumah, kondisi garasi, atau fitur tambahan lainnya.
#
# Melalui pemahaman ini tentang hubungan antara luas garasi dan harga jual rumah, pemilik rumah atau agen real estat dapat membuat keputusan yang lebih terinformasi dalam menentukan harga jual atau melakukan investasi dalam perbaikan garasi.
