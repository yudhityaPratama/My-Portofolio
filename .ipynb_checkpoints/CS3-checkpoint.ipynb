# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#melihat semua row dan column
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#import standarscaller
from sklearn.preprocessing import StandardScaler, LabelEncoder

#import libraries untuk classification project
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

#libraries for evaluation classification project
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score, ConfusionMatrixDisplay, roc_auc_score, roc_curve, RocCurveDisplay

# %%
df = pd.read_csv('AIDS.csv')
df.head()
# Out:
#    time  trt  age     wtkg  hemo  homo  drugs  karnof  oprior  z30  preanti  \
# 0   948    2   48  89.8128     0     0      0     100       0    0        0
# 1  1002    3   61  49.4424     0     0      0      90       0    1      895
# 2   961    3   45  88.4520     0     1      1      90       0    1      707
# 3  1166    3   47  85.2768     0     1      0     100       0    1     1399
# 4  1090    0   43  66.6792     0     1      0     100       0    1     1352
#
#    race  gender  str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  \
# 0     0       0     0      1        0      1       0   422    477   566
# 1     0       0     1      3        0      1       0   162    218   392
# 2     0       1     1      3        0      1       1   326    274  2063
# 3     0       1     1      3        0      1       0   287    394  1590
# 4     0       1     1      3        0      0       0   504    353   870
#
#    cd820  infected
# 0    324         0
# 1    564         1
# ...

# %%
df.describe()
# Out:
#               time          trt          age         wtkg         hemo  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean    879.098177     1.520804    35.248247    75.125311     0.084151
# std     292.274324     1.127890     8.709026    13.263164     0.277680
# min      14.000000     0.000000    12.000000    31.000000     0.000000
# 25%     727.000000     1.000000    29.000000    66.679200     0.000000
# 50%     997.000000     2.000000    34.000000    74.390400     0.000000
# 75%    1091.000000     3.000000    40.000000    82.555200     0.000000
# max    1231.000000     3.000000    70.000000   159.939360     1.000000
#
#               homo        drugs       karnof       oprior          z30  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean      0.661057     0.131370    95.446470     0.021973     0.550257
# std       0.473461     0.337883     5.900985     0.146629     0.497584
# ...

# %%
df.shape
# Out:
# (2139, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      2139 non-null   int64
#  1   trt       2139 non-null   int64
#  2   age       2139 non-null   int64
#  3   wtkg      2139 non-null   float64
#  4   hemo      2139 non-null   int64
#  5   homo      2139 non-null   int64
#  6   drugs     2139 non-null   int64
#  7   karnof    2139 non-null   int64
#  8   oprior    2139 non-null   int64
#  9   z30       2139 non-null   int64
#  10  preanti   2139 non-null   int64
#  11  race      2139 non-null   int64
#  12  gender    2139 non-null   int64
#  13  str2      2139 non-null   int64
#  14  strat     2139 non-null   int64
#  15  symptom   2139 non-null   int64
#  16  treat     2139 non-null   int64
#  17  offtrt    2139 non-null   int64
#  18  cd40      2139 non-null   int64
#  19  cd420     2139 non-null   int64
# ...

# %%
for column in df.columns:
    print(f"============= {column} =================")
    display(df[column].value_counts())
    print()
# Out:
# ============= time =================
# time
# 1087    34
# 1088    24
# 1154    18
# 1091    16
# 1090    16
# 1089    16
# 993     15
# 1132    14
# 1097    13
# 1117    13
# 1139    12
# 1140    12
# 1014    12
# 1064    11
# 990     11
# 1098    11
# 1119    11
# 986     11
# 1133    11
# 1104    11
# 1138    11
# 896     11
# 1068    10
# 1096    10
# 1123    10
# 987     10
# 1012    10
# 1147    10
# 1160    10
# 1110    10
# 1145    10
# 1101     9
# 1116     9
# 977      9
# 1032     9
# 1081     9
# 1124     9
# 980      9
# 1152     9
# 1146     9
# 1077     9
# 948      9
# 1066     9
# 1042     9
# 1153     8
# 476      8
# 1069     8
# 1062     8
# 1112     8
# 991      8
# 1034     8
# 1095     8
# 999      8
# 1063     8
# 392      8
# 1126     8
# 1002     8
# 1167     8
# 959      8
# 1157     8
# 975      7
# 1049     7
# 561      7
# 984      7
# 963      7
# 1021     7
# 1054     7
# 1121     7
# 1065     7
# 981      7
# 1151     7
# 477      7
# 1041     7
# ...

# %%
print("Before drop duplicated data")
df.shape
# Out:
# Before drop duplicated data
# (2139, 23)

# %%
df = df.drop_duplicates(keep='first')

# %%
print("After drop duplicated data")
df.shape
# Out:
# After drop duplicated data
# (2139, 23)

# %%
df.isna().sum()
# Out:
# time        0
# trt         0
# age         0
# wtkg        0
# hemo        0
# homo        0
# drugs       0
# karnof      0
# oprior      0
# z30         0
# preanti     0
# race        0
# gender      0
# str2        0
# strat       0
# symptom     0
# treat       0
# offtrt      0
# cd40        0
# cd420       0
# cd80        0
# cd820       0
# infected    0
# dtype: int64

# %%
sns.histplot(df['age'])
plt.title("Distribusi Usia")
plt.ylabel('Frekuensi')
plt.xlabel('Usia')
plt.show()
# Out:
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Insight dari grafik
# # 1. Puncak distribusi: Perhatikan di mana puncak distribusi umur berada. Misalnya, jika puncaknya berada di rentang usia 20-30,
# #    ini menunjukkan bahwa mayoritas data berada dalam rentang usia tersebut.
# # 2. Sebaran data: Amati bagaimana data tersebar. Apakah terdapat banyak data pada rentang usia tertentu? Apakah distribusi data simetris atau miring ke salah satu sisi?
# # 3. Outliers: Periksa apakah ada nilai outlier, yaitu nilai umur yang sangat sedikit dibandingkan dengan umur lainnya, yang mungkin memerlukan analisis lebih lanjut.
# # 4. Keseluruhan bentuk distribusi: Tentukan apakah distribusi mendekati normal, bimodal, atau memiliki karakteristik lainnya.

# %%
# Check outliers using boxplot
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(df['age'])
plt.title("Boxplot of Age")
plt.ylabel('Age')
plt.xlabel('Data Points')
plt.show()

# %% [markdown]
# Insight:
# 1. Jika median age adalah sekitar 55, ini menunjukkan bahwa populasi data ini memiliki distribusi usia yang condong ke arah usia yang lebih tua.
# 2. Jika IQR sangat besar, misalnya dari 35 hingga 70, ini menunjukkan bahwa ada variasi besar dalam distribusi usia.
# 3. Jika ada beberapa outlier di atas 90, ini mungkin menunjukkan adanya individu yang usianya sangat tua dalam data.
# 4. Jika whiskers lebih panjang di satu sisi (misalnya lebih panjang ke arah usia yang lebih tinggi), ini menunjukkan skewness dalam distribusi usia, dimana ada lebih banyak nilai yang lebih tinggi dibandingkan nilai yang lebih rendah.

# %%
# Filter data
x = df["age"][(df["age"] < 55) & (df["age"] > 20)]

# Plot boxplot
sns.boxplot(x=x)
plt.xlabel(x.name)  # Judul label sumbu x sesuai dengan nama kolom yang difilter
plt.ylabel('Age Distribution')  # Menampilkan judul label sumbu y
plt.title("Age Distribution Boxplot for Ages 21 to 54")
# Show plot
plt.show()

# %% [markdown]
# Insight:
# 1. Median Usia Insight: Median usia dalam kelompok yang difilter ini sekitar 35 tahun, menunjukkan kecenderungan sentral di pertengahan 30-an.
# 2. IQR Insight: Rentang interkuartil adalah dari sekitar 28 hingga 45 tahun, menunjukkan bahwa 50% individu berada dalam rentang usia ini.
# 3. Whiskers Insight: Whiskers memanjang dari sekitar 22 hingga 52 tahun, menunjukkan penyebaran sebagian besar data.
# 4. Outliers Insight: Ada beberapa outliers di luar 52 tahun, menunjukkan sejumlah kecil individu yang secara signifikan lebih tua dalam rentang ini.

# %%
df['infected'].value_counts()
# Out:
# infected
# 0    1618
# 1     521
# Name: count, dtype: int64

# %%
sns.countplot(x="infected",data=df);
plt.title("Jumlah Kasus Infeksi")
plt.show()

# %%
# Assign 'TARGET' column to y 
y = df['infected'].values
# Assign all columns except 'TARGET' to X
X = df.drop(['infected'], axis = 1).values

# %%
from imblearn import under_sampling, over_sampling

#X = df_numeric.drop(['survived'],axis=1)
#y = df_numeric['survived']

# Undersampling
X_under, y_under = under_sampling.RandomUnderSampler().fit_resample(X, y)

# Overampling
#X_over, y_over = over_sampling.RandomOverSampler().fit_resample(X, y)

# Overampling with smote
#X_over_smote, y_over_smote = over_sampling.SMOTE().fit_resample(X, y)

# %%
#Split data into Train and Test 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_under, y_under, test_size=0.2,random_state =42)
print("X_train dataset: ", x_train.shape)
print("y_train dataset: ", y_train.shape)
print("X_test dataset: ", x_test.shape)
print("y_test dataset: ", y_test.shape)
# Out:
# X_train dataset:  (833, 22)
# y_train dataset:  (833,)
# X_test dataset:  (209, 22)
# y_test dataset:  (209,)

# %%
# %%KNN Classification
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3) #set K neighbor as 3
knn.fit(x_train,y_train) #MACHINE LEARNING SEDANG DALAM PROSES BELAJAR
predicted_y = knn.predict(x_test)
print("KNN accuracy according to K=3 is :",knn.score(x_test,y_test))
# Out:
# KNN accuracy according to K=3 is : 0.8038277511961722

# %%
score_array = []
for each in range(1,25):
    knn_loop = KNeighborsClassifier(n_neighbors = each) #set K neighbor as 3
    knn_loop.fit(x_train,y_train)
    score_array.append(knn_loop.score(x_test,y_test))
    
plt.plot(range(1,25),score_array)
plt.title("KNN Score and Range")
plt.xlabel("Range")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# # Insight:
# # Grafik menunjukkan perubahan skor klasifikasi seiring dengan peningkatan jumlah tetangga.
# # Dapat dilihat bahwa skor meningkat secara signifikan dari 1 hingga sekitar 10 tetangga,
# # kemudian skor cenderung stabil setelahnya. Hal ini menunjukkan bahwa model mendapat
# # manfaat dari informasi tambahan yang diberikan oleh tetangga terdekat, namun setelah
# # titik tertentu, penambahan lebih banyak tetangga tidak memberikan peningkatan skor yang
# # signifikan.

# %%
knn_model = KNeighborsClassifier(n_neighbors = 7) #set K neighbor
knn_model.fit(x_train,y_train)
predicted_y = knn_model.predict(x_test)
accuracy_knn = knn_model.score(x_test,y_test)
print("KNN accuracy according to K=7 is :",accuracy_knn)
# Out:
# KNN accuracy according to K=7 is : 0.8133971291866029

# %%
# %%Logistic regression classification
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(x_train,y_train)
accuracy_lr = lr_model.score(x_test,y_test)
print("Logistic Regression accuracy is :",accuracy_lr)
# Out:
# Logistic Regression accuracy is : 0.84688995215311
# D:\APLIKASI\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
accuracy_dt = dt_model.score(x_test,y_test)
print("Decision Tree accuracy is :",accuracy_dt)
# Out:
# Decision Tree accuracy is : 0.8325358851674641

# %%
#Random Forest Classification
from sklearn.ensemble import RandomForestClassifier
rf_model_initial = RandomForestClassifier(n_estimators = 5, random_state = 1)
rf_model_initial.fit(x_train,y_train)
print("Random Forest accuracy for 5 trees is :",rf_model_initial.score(x_test,y_test))
# Out:
# Random Forest accuracy for 5 trees is : 0.84688995215311

# %%
score_array = []
for each in range(1,50):
    rf_loop = RandomForestClassifier(n_estimators = each, random_state = 1) #set K neighbor as 3
    rf_loop.fit(x_train,y_train)
    score_array.append(rf_loop.score(x_test,y_test))
    
plt.plot(range(1,50),score_array)
plt.xlabel("Range")
plt.ylabel("Score")
plt.title("Grafik Score and Range")
plt.show()

# %% [markdown]
# # Insight:
# Dari grafik ini, terlihat bahwa nilai score model RandomForestClassifier meningkat seiring dengan peningkatan jumlah estimator, namun setelah sekitar 20 estimator, peningkatannya menjadi lebih lambat.

# %%
rf_model = RandomForestClassifier(n_estimators = 7, random_state = 1) #set tree number
rf_model.fit(x_train,y_train)
accuracy_rf = rf_model.score(x_test,y_test)
print("Random Forest accuracy for 7 trees is :",accuracy_rf)
# Out:
# Random Forest accuracy for 7 trees is : 0.861244019138756

# %%
#Naive Bayes Classification
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
nb_model.fit(x_train,y_train)
accuracy_nb = nb_model.score(x_test,y_test)
print("Naive Bayes accuracy is :",accuracy_nb)
# Out:
# Naive Bayes accuracy is : 0.7942583732057417

# %%
def model_evaluation(model,name):
    confusion_matrix = pd.crosstab(y_test, model, rownames=['Actual'], colnames=['Predicted'], margins = True)
    sns.heatmap(confusion_matrix, square=True, annot=True, fmt='d', cbar=False)
    plt.xlabel('Prediction label')
    plt.ylabel('True Label');
    plt.title(name)
    plt.yticks([0.5,1.5], [ 'NO', 'YES'],va='center')
    plt.xticks([0.5,1.5], [ 'NO', 'YES'],va='center')
    plt.show()

# %%
# the function that prints all scores
def print_scores(headline, y_true, y_pred):
    print(headline)
    acc_score = accuracy_score(y_true, y_pred)
    print("accuracy: ",acc_score)
    pre_score = precision_score(y_true, y_pred)
    print("precision: ",pre_score)
    rec_score = recall_score(y_true, y_pred)                            
    print("recall: ",rec_score)
    f_score = f1_score(y_true, y_pred, average='weighted')
    print("f1_score: ",f_score)

# %%
print_scores("========Logistic Regression=========;",y_test, lr_model.predict(x_test))
print('========================')
print_scores("=========Naive Bayes=========;",y_test, nb_model.predict(x_test))
print('========================')
print_scores("=========Decision Tree=========;",y_test, dt_model.predict(x_test))
print('========================')
print_scores("=========Random Forest=========;",y_test, rf_model.predict(x_test))
print_scores("=========KNN=========;",y_test, knn.predict(x_test))
print('========================')
# Out:
# ========Logistic Regression=========;
# accuracy:  0.84688995215311
# precision:  0.8586956521739131
# recall:  0.8061224489795918
# f1_score:  0.8464870309745656
# ...
# =========Naive Bayes=========;
# accuracy:  0.7942583732057417
# precision:  0.7956989247311828
# recall:  0.7551020408163265
# f1_score:  0.7938312969225236
# ...
# =========Decision Tree=========;
# accuracy:  0.8325358851674641
# precision:  0.8181818181818182
# recall:  0.826530612244898
# f1_score:  0.8325820429040558
# ...
# =========Random Forest=========;
# accuracy:  0.861244019138756
# precision:  0.8285714285714286
# recall:  0.8877551020408163
# f1_score:  0.8613775453432736
# =========KNN=========;
# accuracy:  0.8038277511961722
# precision:  0.7821782178217822
# recall:  0.8061224489795918
# f1_score:  0.8039627909489111
# ...

# %%
model_evaluation(rf_model.predict(x_test),"Random Forest")

# %% [markdown]
# insight:
# 1. hasil evaluation random forest memperlihatkan true negative (FN) = 93 dan false positive (FP) = 18

# %%
model_evaluation(dt_model.predict(x_test),"Decision Tree")

# %% [markdown]
# insight:
# 1. hasil evaluation decision tree memperlihatkan true negative (FN) = 93 dan false positive (FP) = 18

# %%
lr_y_pred = lr_model.predict(x_test)
model_evaluation(lr_y_pred,"Logistic Regression")

# %% [markdown]
# insight:
# 1. hasil evaluation Logistic Regression memperlihatkan true negative (FN) = 98 dan false positive (FP) = 13

# %%
knn_model =  knn.predict(x_test)
model_evaluation(knn_model,"KNN")

# %% [markdown]
# insight:
# 1. hasil evaluation KNN memperlihatkan true negative (FN) = 89 dan false positive (FP) = 22

# %%
model_evaluation(nb_model.predict(x_test),"Naive Bayes")

# %% [markdown]
# insight:
# 1. hasil evaluation Naive Bayes memperlihatkan true negative (FN) = 92 dan false positive (FP) = 19

# %% [markdown]
# kesimpulannya:
# 1.Model Terbaik:
# Dari hasil evaluasi, Random Forest (RF) adalah model yang memberikan performa tertinggi. Hal ini didukung oleh akurasi yang tinggi dan seimbang antara precision, recall, serta F1-score.
# 2.Pemilihan Parameter Evaluasi:
# Akurasi: Dipilih sebagai parameter utama untuk mengevaluasi performa model. Akurasi adalah metrik yang paling sederhana dan mudah dipahami, karena merupakan rasio antara jumlah prediksi yang benar dengan total jumlah prediksi. Dalam konteks masalah klasifikasi ini, akurasi memberikan gambaran umum tentang seberapa baik model dapat memprediksi kelas target. Namun, perlu diingat bahwa dalam kasus dataset yang tidak seimbang (seperti yang telah diundersampling), akurasi mungkin tidak memberikan gambaran yang akurat tentang performa model, sehingga penting juga untuk mempertimbangkan metrik lain seperti precision, recall, dan F1-score.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Memuat dataset
df = pd.read_csv('AIDS.csv')

# Visualisasi distribusi usia
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=30, kde=True)
plt.title('Distribusi Usia Pasien dalam Dataset AIDS')
plt.xlabel('Usia')
plt.ylabel('Frekuensi')
plt.grid(True)
plt.show()
# Out:
# D:\APLIKASI\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
